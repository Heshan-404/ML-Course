# %%
import pandas as pd
df = pd.read_csv("CSV/GPA_data.CSV")

# %%
df[['Gender','Extra_Curricular']] # if we want to get more than one column
# Out:
#      Gender Extra_Curricular
# 0      Male        Societies
# 1    Female        Societies
# 2      Male        Societies
# 3    Female               No
# 4      Male               No
# ..      ...              ...
# 995  Female               No
# 996    Male               No
# 997    Male           Sports
# 998    Male        Societies
# 999    Male               No
#
# [1000 rows x 2 columns]

# %%
df['Gender'] # here  it's not given column label only values
# Out:
# 0        Male
# 1      Female
# 2        Male
# 3      Female
# 4        Male
#         ...
# 995    Female
# 996      Male
# 997      Male
# 998      Male
# 999      Male
# Name: Gender, Length: 1000, dtype: object

# %%
dummy = pd.get_dummies(df[["Gender","Extra_Curricular"]])
dummy
# Out:
#      Gender_Female  Gender_Male  Extra_Curricular_No  \
# 0            False         True                False
# 1             True        False                False
# 2            False         True                False
# 3             True        False                 True
# 4            False         True                 True
# ..             ...          ...                  ...
# 995           True        False                 True
# 996          False         True                 True
# 997          False         True                False
# 998          False         True                False
# 999          False         True                 True
#
#      Extra_Curricular_Societies  Extra_Curricular_Sports
# 0                          True                    False
# 1                          True                    False
# 2                          True                    False
# 3                         False                    False
# ...

# %%
dummy = dummy.astype('int')
dummy.head()
# Out:
#    Gender_Female  Gender_Male  Extra_Curricular_No  \
# 0              0            1                    0
# 1              1            0                    0
# 2              0            1                    0
# 3              1            0                    1
# 4              0            1                    1
#
#    Extra_Curricular_Societies  Extra_Curricular_Sports
# 0                           1                        0
# 1                           1                        0
# 2                           1                        0
# 3                           0                        0
# 4                           0                        0

# %%
dummy = pd.get_dummies(df[["Gender","Extra_Curricular"]],dtype=int)
dummy
# Out:
#      Gender_Female  Gender_Male  Extra_Curricular_No  \
# 0                0            1                    0
# 1                1            0                    0
# 2                0            1                    0
# 3                1            0                    1
# 4                0            1                    1
# ..             ...          ...                  ...
# 995              1            0                    1
# 996              0            1                    1
# 997              0            1                    0
# 998              0            1                    0
# 999              0            1                    1
#
#      Extra_Curricular_Societies  Extra_Curricular_Sports
# 0                             1                        0
# 1                             1                        0
# 2                             1                        0
# 3                             0                        0
# ...

# %%
dummy.drop(["Gender_Female","Extra_Curricular_No"],axis=1,inplace=True) # dummy trapping remove reference columns

# %%
dummy.drop(2,inplace=True,axis=0) # if we want to remove a row inplace mean reasign to dummy otherwise it will return only

# %%
df.drop(["Gender","Extra_Curricular"],axis=1,inplace=True)
df.head()
# Out:
#      ID  Age  Study_Hours  Annual_Income  Distance_From_Home   GPA
# 0  8867   22           10        1318792                 154  1.76
# 1  1316   24            9         874657                 181  3.88
# 2  9443   22           15        1098331                  94  1.73
# 3  1829   25            9        1680585                   8  1.29
# 4  1989   26            7        1361560                 122  3.19

# %%
df.drop(['ID'],axis=1,inplace=True) # id is a just a representative .. It don't want to analyizing it is just a number

# %%
data_new = pd.concat([dummy,df],axis=1)
data_new.head()
# Out:
#    Gender_Male  Extra_Curricular_Societies  Extra_Curricular_Sports  Age  \
# 0          1.0                         1.0                      0.0   22
# 1          0.0                         1.0                      0.0   24
# 3          0.0                         0.0                      0.0   25
# 4          1.0                         0.0                      0.0   26
# 5          0.0                         1.0                      0.0   25
#
#    Study_Hours  Annual_Income  Distance_From_Home   GPA
# 0           10        1318792                 154  1.76
# 1            9         874657                 181  3.88
# 3            9        1680585                   8  1.29
# 4            7        1361560                 122  3.19
# 5            5         887824                 107  2.42
