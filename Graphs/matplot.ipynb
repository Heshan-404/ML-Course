# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
L1 = [1,2,3,4]
L2 = [10,24,36,58]
plt.plot(L1,L2)
plt.show()

# %%
plt.figure(figsize=(10,7))
plt.plot(L1,L2)
plt.xlabel('Index')
plt.ylabel('Marks')
plt.title('Marks of Student')
plt.show()

# %%
df = pd.read_csv("C:\\Users\\Heshan\\PycharmProjects\\ML-Course\\CSV\\default.csv")
df.head()
# Out:
#    Gender  Loan.Offered        Job  Work.Exp  Credit.Score  EMI.Ratio Status  \
# 0    Male             0  unskilled        14            86        3.0     No
# 1  Female             1    skilled        15            94        3.0     No
# 2    Male             0  unskilled        16            86        3.0     No
# 3  Female             1    skilled        13            94        3.0     No
# 4    Male             1    skilled        12            85        3.3     No
#
#   Credit.History  Own house   Purpose  Dependents
# 0           poor          1  personal           2
# 1           poor          1  personal           3
# 2           poor          1  personal           2
# 3           poor          1  personal           3
# 4           poor          1  personal           2

# %%
plt.scatter(df['Work.Exp'],df['Credit.Score'])
plt.xlabel('Work Experience')
plt.ylabel('Credit Score')
plt.title('Credit Score against the work experience')
plt.show()

# %%
plt.plot(df['Work.Exp'],df['Credit.Score'])
plt.xlabel('Work Experience')
plt.ylabel('Credit Score')
plt.title('Credit Score against the work experience')
plt.show()

# %%
df = pd.DataFrame({'Loc1':[0,10,20],'Loc2':[10,0,15],'Loc3':[20,15,0]},index=['loc1','loc2','loc3'])
df
# Out:
#       Loc1  Loc2  Loc3
# loc1     0    10    20
# loc2    10     0    15
# loc3    20    15     0

# %%
sns.heatmap(df,annot=True)
plt.show()
