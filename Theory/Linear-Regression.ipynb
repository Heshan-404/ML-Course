# %%
import numpy as np
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score
import matplotlib.pyplot as plt

# %%
x = np.array([1,2,3,4,5]).reshape(-1,1) # all are will be into single column
y = np.array([2,3,5,6,7])
print(x)
print(y)
# Out:
# [[1]
#  [2]
#  [3]
#  [4]
#  [5]]
# [2 3 5 6 7]

# %%
plt.plot(x,y,color="red")
plt.show()

# %%
model = LinearRegression()

# %%
model.fit(x,y)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(x)

# %%
r2 = r2_score(y,y_pred)
print(f"R-squared : {r2}")
# Out:
# R-squared : 0.9825581395348837

# %%
a = np.array([100,88,32]).reshape(-1,1)
model.predict(a)
# Out:
# array([130.7, 115.1,  42.3])

# %%
model.intercept_
# Out:
# 0.6999999999999988

# %%
model.coef_
# Out:
# array([1.3])
